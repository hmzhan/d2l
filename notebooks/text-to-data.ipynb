# %%
GITHUB_TOKEN = "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"
USER = "hmzhan"
CLONE_URL = f"https://{USER}:{GITHUB_TOKEN}@github.com/{USER}/d2l.git"
get_ipython().system(f"git clone {CLONE_URL}")
# Out:
# Cloning into 'd2l'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 109 (delta 11), reused 13 (delta 5), pack-reused 88
# Receiving objects: 100% (109/109), 11.10 MiB | 17.56 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
import sys
sys.path.append("d2l")
from d2l import text_to_data

# %%
batch_size = 64
num_steps = 10
data = text_to_data.TimeMachine(batch_size = 64, num_steps = 10)

# %%
raw_text = data._download()

# %%
raw_text[:60]
# Out:
# 'The Time Machine, by H. G. Wells [1898]\n\n\n\n\nI\n\n\nThe Time Tra'

# %%
text = data._preprocess(raw_text)
text[:60]
# Out:
# '     ,    .  .   [1898]\n\n\n\n\n \n\n\n      (                   )\n'

# %%
tokens = data._tokenize(text)
','.join(tokens[:30])
# Out:
# ' , , , , ,,, , , , ,., , ,., , , ,[,1,8,9,8,],\n,\n,\n,\n,\n, ,\n'

# %%
vocab = text_to_data.Vocab(tokens)
indices = vocab[tokens[:10]]
print(indices)
print(vocab.to_tokens(indices))
# Out:
# [1, 1, 1, 1, 1, 7, 1, 1, 1, 1]
# [' ', ' ', ' ', ' ', ' ', ',', ' ', ' ', ' ', ' ']

# %%
words = text.split()
vocab = text_to_data.Vocab(words)
vocab.token_freqs[:10]
# Out:
# [(',', 2149),
#  ('.', 1709),
#  ("'", 478),
#  ('-', 190),
#  ('--', 158),
#  (';', 113),
#  (",'", 62),
#  ('?', 51),
#  (".'", 48),
#  ('!', 47)]

# %%
text
# Out:
# '     ,    .  .   [1898]\n\n\n\n\n \n\n\n      (                   )\n             .          \n ,                  .  \n     ,              \n                       \n       .    ,      ,    \n                 ,        \n   -           \n           .                \n --             --         \n              (       )\n     .\n\n\'         .                \n           .    ,  \n ,                    .\'\n\n\'                         ?\'\n   ,            .\n\n\'                       \n     .                      .  \n             ,         _ _,\n       .        ?      \n   .          .\'\n\n\'       ,\'      .\n\n\' ,      ,  ,    ,          \n   .\'\n\n\'     ,\'    . \'             .  \n   --\'\n\n\'       .        .     _ _\n   ?\'\n\n\' \'     ,\'    .\n\n\'                       ,      \n ?\'\n\n     . \' ,\'        , \' \n            _ _  :      \n ,  ,  ,  -- .        \n       ,                  ,  \n         .          ,\n                 ,      ,  .\n   ,  ,              
# ...
